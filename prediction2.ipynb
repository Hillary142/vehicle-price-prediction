# %%
import pandas as pd
import warnings as w
import datetime as d
import seaborn as s

# %%
w.filterwarnings('ignore')

# %%
df = pd.read_csv('cars.csv')
data=pd.read_csv("cars.csv")

# %%
data.tail(5)
# Out:
#             Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  \
# 245        Honda Fit  2017     4522440.78     5525534.01      219765
# 246      Mazda Demio  2015     2421640.34     3046698.46       61815
# 247  Subaru Forester  2022     3148227.62     1244814.27      187335
# 248      Mazda Demio  2006      804445.12     5669607.02       57335
# 249  Subaru Forester  2019     3730710.15     1506336.11      234068
#
#     Fuel_Type Seller_Type Transmission  Owner
# 245    Petrol  Individual       Manual      4
# 246    Diesel      Dealer       Manual      3
# 247    Hybrid  Individual       Manual      4
# 248    Hybrid      Dealer       Manual      1
# 249    Petrol      Dealer       Manual      2

# %%
data.shape
# Out:
# (250, 9)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       250 non-null    object
#  1   Year           250 non-null    int64
#  2   Selling_Price  250 non-null    float64
#  3   Present_Price  250 non-null    float64
#  4   Kms_Driven     250 non-null    int64
#  5   Fuel_Type      250 non-null    object
#  6   Seller_Type    250 non-null    object
#  7   Transmission   250 non-null    object
#  8   Owner          250 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 17.7+ KB

# %%
data.isnull()
# Out:
#      Car_Name   Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  \
# 0       False  False          False          False       False      False
# 1       False  False          False          False       False      False
# 2       False  False          False          False       False      False
# 3       False  False          False          False       False      False
# 4       False  False          False          False       False      False
# ..        ...    ...            ...            ...         ...        ...
# 245     False  False          False          False       False      False
# 246     False  False          False          False       False      False
# 247     False  False          False          False       False      False
# 248     False  False          False          False       False      False
# 249     False  False          False          False       False      False
#
#      Seller_Type  Transmission  Owner
# 0          False         False  False
# 1          False         False  False
# 2          False         False  False
# 3          False         False  False
# 4          False         False  False
# ..           ...           ...    ...
# 245        False         False  False
# 246        False         False  False
# 247        False         False  False
# 248        False         False  False
# 249        False         False  False
#
# [250 rows x 9 columns]

# %%
data.describe()
# Out:
#        Selling_Price  Present_Price     Kms_Driven   Fuel_Type  Seller_Type  \
# count   2.500000e+02   2.500000e+02     250.000000  199.000000   250.000000
# mean    2.738491e+06   3.190610e+06  132716.996000    0.939698     0.524000
# std     1.340744e+06   1.668937e+06   69416.237182    0.844699     0.500426
# min     3.515317e+05   3.046066e+05   10273.000000    0.000000     0.000000
# 25%     1.565220e+06   1.732037e+06   71560.000000    0.000000     0.000000
# 50%     2.815735e+06   3.361078e+06  133991.000000    1.000000     1.000000
# 75%     3.827888e+06   4.627293e+06  191301.500000    2.000000     1.000000
# max     4.992861e+06   5.987291e+06  249111.000000    2.000000     1.000000
#
#        Transmission       Owner         Age
# count    250.000000  250.000000  250.000000
# mean       0.496000    2.404000   10.816000
# std        0.500987    1.137524    5.745449
# min        0.000000    1.000000    1.000000
# 25%        0.000000    1.000000    6.000000
# 50%        0.000000    2.000000   11.000000
# 75%        1.000000    3.000000   16.000000
# max        1.000000    4.000000   20.000000

# %%
date_time=d.datetime.now()
date_time.year-data['Year']
# Out:
# 0      16
# 1       9
# 2      20
# 3      16
# 4       9
#        ..
# 245     8
# 246    10
# 247     3
# 248    19
# 249     6
# Name: Year, Length: 250, dtype: int64

# %%
data['Age']=date_time.year-data['Year']
data.head(4)
# Out:
#          Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       Honda Fit  2009      798583.37     1011303.41      126991    Petrol
# 1       Honda Fit  2016     4989829.89      898997.70      129670    Diesel
# 2  Nissan X-Trail  2005      671428.20     4115746.84       18270    Petrol
# 3     Mazda Demio  2009     1689224.70     4641333.20       99713    Hybrid
#
#   Seller_Type Transmission  Owner  Age
# 0      Dealer       Manual      2   16
# 1  Individual       Manual      3    9
# 2  Individual       Manual      2   20
# 3  Individual       Manual      1   16

# %%
data.drop('Year',axis=1,inplace=True)
data.head()
# Out:
#          Car_Name  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       Honda Fit      798583.37     1011303.41      126991    Petrol
# 1       Honda Fit     4989829.89      898997.70      129670    Diesel
# 2  Nissan X-Trail      671428.20     4115746.84       18270    Petrol
# 3     Mazda Demio     1689224.70     4641333.20       99713    Hybrid
# 4  Toyota Corolla     2992221.00     4762202.45      163827    Petrol
#
#   Seller_Type Transmission  Owner  Age
# 0      Dealer       Manual      2   16
# 1  Individual       Manual      3    9
# 2  Individual       Manual      2   20
# 3  Individual       Manual      1   16
# 4      Dealer    Automatic      1    9

# %%
s.boxplot(data['Selling_Price'])
# Out:
# <Axes: ylabel='Selling_Price'>

# %%
sorted(data['Selling_Price'],reverse=True)
# Out:
# [4992860.86,
#  4989829.89,
#  4989069.87,
#  4979498.86,
#  4974093.89,
#  4969029.06,
#  4958489.89,
#  4952548.81,
#  4916976.11,
#  4904597.96,
#  4863632.82,
#  4854482.51,
#  4835314.35,
#  4829410.54,
#  4824450.47,
#  4814607.38,
#  4759792.81,
#  4753786.88,
#  4723394.24,
#  4676997.27,
#  4672424.09,
#  4659877.67,
#  4649381.59,
#  4645815.46,
#  4620374.26,
#  4596262.6,
#  4589449.74,
#  4559316.82,
#  4543392.92,
#  4522440.78,
#  4511084.46,
#  4494224.14,
#  4433649.22,
#  4368280.47,
#  4362419.56,
#  4355090.1,
#  4348169.01,
#  4336179.22,
#  4325273.24,
#  4277386.94,
#  4243406.2,
#  4225378.3,
#  4223472.01,
#  4202061.26,
#  4195525.99,
#  4182337.7,
#  4175380.31,
#  4071722.65,
#  4047459.57,
#  4022128.27,
#  3993336.1,
#  3987105.52,
#  3985242.7,
#  3982478.05,
#  3976893.67,
#  3966687.45,
#  3960912.3,
#  3932031.04,
#  3909606.44,
#  3907286.65,
#  3896826.34,
#  3840544.1,
#  3831203.0,
#  3817943.2,
#  3816772.19,
#  3742547.69,
#  3739852.21,
#  3730710.15,
#  3716450.55,
#  3684027.92,
#  3679035.49,
#  3643059.12,
#  3597416.69,
#  3587409.96,
#  3571248.47,
#  3563250.11,
#  3541793.48,
#  3531909.64,
#  3516739.19,
#  3514237.02,
#  3513422.11,
#  3511283.82,
#  3495279.29,
#  3473407.6,
#  3458895.57,
#  3434133.96,
#  3410118.32,
#  3399485.95,
#  3389898.73,
#  3381134.37,
#  3358817.31,
#  3353921.39,
#  3324337.56,
#  3323069.63,
#  3319518.72,
#  3315038.97,
#  3308600.94,
#  3298592.35,
#  3287571.96,
#  3258137.24,
#  3224475.8,
#  3206504.5,
#  3192964.38,
#  3185044.99,
#  3182407.03,
#  3175172.23,
#  3157692.07,
#  3148227.62,
#  3070472.9,
#  3062177.58,
#  3054203.16,
#  3047633.34,
#  3017212.05,
#  3005663.66,
#  3000516.45,
#  2992221.0,
#  2973489.46,
#  2965893.92,
#  2960998.33,
#  2934182.36,
#  2904839.08,
#  2857128.29,
#  2849957.64,
#  2848771.17,
#  2843578.08,
#  2787892.45,
#  2781531.02,
#  2779316.72,
#  2772040.39,
#  2763696.23,
#  2726555.06,
#  2716763.59,
#  2658450.26,
#  2657020.47,
#  2641017.34,
#  2623374.11,
#  2602814.37,
#  2596807.47,
#  2590372.21,
#  2558370.5,
#  2554824.48,
#  2540894.53,
#  2484210.62,
#  2474347.65,
#  2452988.94,
#  2421640.34,
#  2419903.52,
#  2405425.86,
#  2390547.98,
#  2379771.9,
#  2354948.06,
#  2348159.88,
#  2339200.69,
#  2282155.72,
#  2265542.28,
#  2242768.11,
#  2204557.52,
#  2198630.39,
#  2186359.39,
#  2175759.33,
#  2173685.81,
#  2172481.65,
#  2144875.4,
#  2085848.52,
#  2070201.67,
#  2060521.39,
#  2045905.31,
#  2024308.0,
#  2015960.02,
#  2008192.02,
#  1929141.55,
#  1900781.49,
#  1898139.43,
#  1864282.8,
#  1863261.8,
#  1844178.26,
#  1815155.19,
#  1802858.57,
#  1794333.55,
#  1786076.97,
#  1746011.44,
#  1705780.23,
#  1689224.7,
#  1636868.21,
#  1632412.82,
#  1611294.87,
#  1575061.13,
#  1561939.32,
#  1510045.48,
#  1472144.64,
#  1471632.57,
#  1469400.24,
#  1468355.9,
#  1445408.38,
#  1435016.13,
#  1395854.26,
#  1342915.61,
#  1336540.11,
#  1326685.67,
#  1321087.82,
#  1317132.38,
#  1304579.76,
#  1302817.44,
#  1269230.95,
#  1265840.36,
#  1265504.49,
#  1177604.67,
#  1175829.84,
#  1154788.46,
#  1143517.24,
#  1129340.9,
#  1105352.42,
#  1101983.69,
#  1082622.43,
#  1015840.5,
#  1008735.16,
#  995895.25,
#  987982.52,
#  954596.96,
#  946339.18,
#  936568.53,
#  927701.74,
#  848265.71,
#  824699.32,
#  810545.03,
#  804445.12,
#  798583.37,
#  798555.32,
#  772893.15,
#  728631.05,
#  727304.19,
#  695775.54,
#  693618.52,
#  671428.2,
#  653326.4,
#  626010.26,
#  611727.99,
#  606105.98,
#  600969.2,
#  598584.27,
#  598175.68,
#  595742.3,
#  574984.49,
#  480068.5,
#  466136.25,
#  465367.34,
#  399872.44,
#  378214.58,
#  375898.06,
#  351531.7]

# %%
data[(data['Selling_Price']>=33.0) & (data['Selling_Price']<=35.0)]
# Out:
# Empty DataFrame
# Columns: [Car_Name, Selling_Price, Present_Price, Kms_Driven, Fuel_Type, Seller_Type, Transmission, Owner, Age]
# Index: []

# %%
data=data[~(data['Selling_Price']>=33.0) & (data['Selling_Price']<=35.0)]
data.shape
# Out:
# (0, 9)

# %%
data.head(11)
# Out:
#           Car_Name  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0        Honda Fit      798583.37     1011303.41      126991    Petrol
# 1        Honda Fit     4989829.89      898997.70      129670    Diesel
# 2   Nissan X-Trail      671428.20     4115746.84       18270    Petrol
# 3      Mazda Demio     1689224.70     4641333.20       99713    Hybrid
# 4   Toyota Corolla     2992221.00     4762202.45      163827    Petrol
# 5        Honda Fit     2144875.40      438493.29      223374    Diesel
# 6        Honda Fit     4759792.81     4435131.19      218934    Diesel
# 7      Mazda Demio     1863261.80      930796.03      134114    Hybrid
# 8        Honda Fit      351531.70     3978696.09      207207  Electric
# 9   Toyota Corolla     4974093.89     3417169.12      132621    Hybrid
# 10  Toyota Corolla     2965893.92     4421290.39       10273    Hybrid
#
#    Seller_Type Transmission  Owner  Age
# 0       Dealer       Manual      2   16
# 1   Individual       Manual      3    9
# 2   Individual       Manual      2   20
# 3   Individual       Manual      1   16
# 4       Dealer    Automatic      1    9
# 5   Individual    Automatic      4    1
# 6   Individual    Automatic      4   11
# 7       Dealer       Manual      3   17
# 8       Dealer       Manual      2   10
# 9       Dealer    Automatic      1   20
# 10      Dealer       Manual      1   12

# %%
data['Fuel_Type'].unique()
# Out:
# array(['Petrol', 'Diesel', 'Hybrid', 'Electric'], dtype=object)

# %%
data['Fuel_Type']=data['Fuel_Type'].map({'Petrol':0,'Diesel':1,'Hybrid':2})

# %%
data['Fuel_Type'].unique()
# Out:
# array([ 0.,  1.,  2., nan])

# %%
data['Seller_Type'].unique()
# Out:
# array(['Dealer', 'Individual'], dtype=object)

# %%
data['Transmission'].unique()
# Out:
# array(['Manual', 'Automatic'], dtype=object)

# %%
data['Seller_Type']=data['Seller_Type'].map({'Dealer':0,'Individual':1})

# %%
data['Transmission']=data['Transmission'].map({'Manual':0,'Automatic':1})

# %%
data['Seller_Type'].unique()
# Out:
# array([0, 1])

# %%
data['Transmission'].unique()
# Out:
# array([0, 1])

# %%
X=data.drop(['Car_Name','Selling_Price'],axis=1)
y=data['Selling_Price']

# %%
X
# Out:
#      Present_Price  Kms_Driven  Fuel_Type  Seller_Type  Transmission  Owner  \
# 0       1011303.41      126991        0.0            0             0      2
# 1        898997.70      129670        1.0            1             0      3
# 2       4115746.84       18270        0.0            1             0      2
# 3       4641333.20       99713        2.0            1             0      1
# 4       4762202.45      163827        0.0            0             1      1
# ..             ...         ...        ...          ...           ...    ...
# 245     5525534.01      219765        0.0            1             0      4
# 246     3046698.46       61815        1.0            0             0      3
# 247     1244814.27      187335        2.0            1             0      4
# 248     5669607.02       57335        2.0            0             0      1
# 249     1506336.11      234068        0.0            0             0      2
#
#      Age
# 0     16
# 1      9
# 2     20
# 3     16
# 4      9
# ..   ...
# 245    8
# 246   10
# 247    3
# 248   19
# 249    6
#
# [250 rows x 7 columns]

# %%
print(X.isnull().sum())  # for a DataFrame
print(X.isna().any())    # check if any column contains NaN
# Out:
# Present_Price     0
# Kms_Driven        0
# Fuel_Type        51
# Seller_Type       0
# Transmission      0
# Owner             0
# Age               0
# dtype: int64
# Present_Price    False
# Kms_Driven       False
# Fuel_Type         True
# Seller_Type      False
# Transmission     False
# Owner            False
# Age              False
# dtype: bool

# %%
X = X.dropna()
print(X.isnull().sum())  # for a DataFrame
print(X.isna().any())    # check if any column contains NaN
# Out:
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# Age              0
# dtype: int64
# Present_Price    False
# Kms_Driven       False
# Fuel_Type        False
# Seller_Type      False
# Transmission     False
# Owner            False
# Age              False
# dtype: bool

# %%
y
print(y.isnull().sum())  # for a DataFrame
print(y.isna().any())    # check if any column contains NaN
# Out:
# 0
# False

# %%
from sklearn.model_selection import train_test_split

# %%
X=data.drop(['Car_Name','Selling_Price'],axis=1)
y=data['Selling_Price']

# %%
X
# Out:
#      Present_Price  Kms_Driven  Fuel_Type  Seller_Type  Transmission  Owner  \
# 0       1011303.41      126991        0.0            0             0      2
# 1        898997.70      129670        1.0            1             0      3
# 2       4115746.84       18270        0.0            1             0      2
# 3       4641333.20       99713        2.0            1             0      1
# 4       4762202.45      163827        0.0            0             1      1
# ..             ...         ...        ...          ...           ...    ...
# 245     5525534.01      219765        0.0            1             0      4
# 246     3046698.46       61815        1.0            0             0      3
# 247     1244814.27      187335        2.0            1             0      4
# 248     5669607.02       57335        2.0            0             0      1
# 249     1506336.11      234068        0.0            0             0      2
#
#      Age
# 0     16
# 1      9
# 2     20
# 3     16
# 4      9
# ..   ...
# 245    8
# 246   10
# 247    3
# 248   19
# 249    6
#
# [250 rows x 7 columns]

# %%
X = X.dropna()

# %%
X
# Out:
#      Present_Price  Kms_Driven  Fuel_Type  Seller_Type  Transmission  Owner  \
# 0       1011303.41      126991        0.0            0             0      2
# 1        898997.70      129670        1.0            1             0      3
# 2       4115746.84       18270        0.0            1             0      2
# 3       4641333.20       99713        2.0            1             0      1
# 4       4762202.45      163827        0.0            0             1      1
# ..             ...         ...        ...          ...           ...    ...
# 245     5525534.01      219765        0.0            1             0      4
# 246     3046698.46       61815        1.0            0             0      3
# 247     1244814.27      187335        2.0            1             0      4
# 248     5669607.02       57335        2.0            0             0      1
# 249     1506336.11      234068        0.0            0             0      2
#
#      Age
# 0     16
# 1      9
# 2     20
# 3     16
# 4      9
# ..   ...
# 245    8
# 246   10
# 247    3
# 248   19
# 249    6
#
# [199 rows x 7 columns]

# %%
y
# Out:
# 0       798583.37
# 1      4989829.89
# 2       671428.20
# 3      1689224.70
# 4      2992221.00
#           ...
# 245    4522440.78
# 246    2421640.34
# 247    3148227.62
# 248     804445.12
# 249    3730710.15
# Name: Selling_Price, Length: 250, dtype: float64

# %%
Xy = pd.concat([X, y], axis=1).dropna()
X = Xy.drop(columns=y.name)
y = Xy[y.name]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.24,random_state=49)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble._forest import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from xgboost import XGBRegressor

# %%
l=LinearRegression()
l.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
r=RandomForestRegressor()
r.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
x=XGBRegressor()
x.fit(X_train,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=None,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
d=DecisionTreeRegressor()
d.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
x=XGBRegressor()
x.fit(X_train,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=None,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
y_predict1=l.predict(X_test)
y_predict2=r.predict(X_test)
y_predict3=d.predict(X_test)
y_predict4=x.predict(X_test)

# %%
from sklearn import metrics

# %%
score_1=metrics.r2_score(y_test,y_predict1)
score_2=metrics.r2_score(y_test,y_predict2)
score_3=metrics.r2_score(y_test,y_predict3)
score_4=metrics.r2_score(y_test,y_predict4)

# %%
Data=pd.DataFrame({'Models':['LinearRegression','RandomForestRegressor','DecisionTreeRegressor','XGBRegressor'],
"R2_Score":[score_1*100,score_2*100,score_3*100,score_4*100]
})
Data
# Out:
#                   Models    R2_Score
# 0       LinearRegression    3.917457
# 1  RandomForestRegressor  -25.847541
# 2  DecisionTreeRegressor -129.805926
# 3           XGBRegressor  -42.040177

# %%
final_model=RandomForestRegressor()
final_model.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
import joblib

# %%
joblib.dump(final_model,'Prediction_Model')
# Out:
# ['Prediction_Model']

# %%
model=joblib.load('Prediction_Model')

# %%
new_data = pd.DataFrame({
    'Present_Price':6.89,
    'Kms_Driven':31000,
    'Fuel_Type':0,
    'Seller_Type':0,
    'Transmission':0,
    'Owner':0,
    'Age':6
},index=[0])

# %%
model.predict(new_data)
# Out:
# array([3379728.5501])
